# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
import matplotlib.pyplot as plt
import altair as alt
from vega_datasets import data
from matplotlib import cm
from math import log10

# %%
CONTEO_DE_PROCESOS = pd.read_csv('C:/Users/maria/Documents/GitHub/VisualAnalytics/Proyecto/CONTEO_DE_PROCESOS.csv', 
                 sep = ',', parse_dates= True,
                        thousands=',', decimal='.' )
CONTEO_DE_PROCESOS.head()
# Out:
#    Unnamed: 0 HECHO RUPTURA CONEXO ESTADO_NOTICIA               ETAPA  \
# 0           0    SI      NO     NO         ACTIVO          INDAGACIÓN
# 1           1    SI      NO     NO         ACTIVO          INDAGACIÓN
# 2           2    SI      NO     NO         ACTIVO              JUICIO
# 3           3    SI      NO     NO       INACTIVO  EJECUCIÓN DE PENAS
# 4           4    SI      NO     NO       INACTIVO          INDAGACIÓN
#
#    ANIO_DENUNCIA  ANIO_ENTRADA  ANIO_HECHO       LEY  ...     MUNICIPIO  \
# 0           2017          2017        2016   Ley 906  ...    FACATATIVÁ
# 1           2020          2020        2020   Ley 906  ...  BOGOTÁ, D.C.
# 2           2020          2020        2020   Ley 906  ...  BOGOTÁ, D.C.
# 3           2017          2017        2017   Ley 906  ...      LA PLATA
# 4           2011          2011        2011  Ley 1098  ...      MEDELLÍN
#
#                                            SECCIONAL           GRUPO_DELITO  \
# 0                DIRECCIÓN SECCIONAL DE CUNDINAMARCA  FALSEDAD EN DOCUMENTO
# 1                      DIRECCIÓN SECCIONAL DE BOGOTÁ                  HURTO
# 2                      DIRECCIÓN SECCIONAL DE BOGOTÁ                  HURTO
# 3  DIRECCION ESPECIALIZADA CONTRA ORGANIZACIONES ...        ESTUPEFACIENTES
# 4                    DIRECCIÓN SECCIONAL DE MEDELLÍN      SEGURIDAD PUBLICA
#
#                                               DELITO CAPTURA IMPUTACION  \
# 0  FALSEDAD IDEOLOGICA EN DOCUMENTO PUBLICO. ART....      NO         NO
# 1  HURTO. ART. 239 C.P. AGRAVADO CUANDO LO HURTAD...      NO         NO
# 2  HURTO CALIFICADO MENOR CUANTIA ART. 240 C.P.  ...      NO         SI
# 3  TRAFICO FABRICACION O PORTE DE ESTUPEFACIENTES...      SI         SI
# 4  OBSTRUCCION A VIAS PUBLICAS QUE AFECTAN EL ORD...      NO         NO
#
#   CONDENA ACUSACION HOMICIDIO_DOLOSO_CONSUMADO TOTAL_PROCESOS
# 0      NO        NO                         NO              1
# 1      NO        NO                         NO            891
# 2      NO        NO                         NO            284
# 3      SI        SI                         NO              1
# 4      NO        NO                         NO              1
#
# [5 rows x 22 columns]

# %% [markdown]
# Datos extraídos de la fuente 'Conteo de Procesos'
#
# Fecha creación: 25 de abril de 2019
#
# Datos actualizados por última vez: 2 de febrero de 2021
#
# Fuente: [Datos Abiertos](https://www.datos.gov.co/resource/q6re-36rh.json)

# %% [markdown]
# La base utilizada trata sobre el total de noticias criminales por delito registrados en el Sistema Penal Oral Acusatorio en la Ley 906 de 2004 y Ley 1098 de 2006 desde hechos ocurridos en 2010. Cuenta con 2'062.269 filas y 22 columnas, el departamento donde se recogieron los datos fue Bogotá D.C, tienen una frecuencia mensual y son del Sector de Justicia y Derecho.

# %%
Base.head(-100)
# Out:
#         HECHO RUPTURA CONEXO ESTADO_NOTICIA               ETAPA  \
# 0          SI      NO     NO         ACTIVO          INDAGACIÓN
# 1          SI      NO     NO         ACTIVO          INDAGACIÓN
# 2          SI      NO     NO         ACTIVO              JUICIO
# 3          SI      NO     NO       INACTIVO  EJECUCIÓN DE PENAS
# 4          SI      NO     NO       INACTIVO          INDAGACIÓN
# ...       ...     ...    ...            ...                 ...
# 2062264    NO      NO     NO       INACTIVO          INDAGACIÓN
# 2062265    SI      NO     NO         ACTIVO         QUERELLABLE
# 2062266    SI      NO     NO         ACTIVO          INDAGACIÓN
# 2062267    SI      NO     NO         ACTIVO          INDAGACIÓN
# 2062268    NO      NO     NO       INACTIVO          INDAGACIÓN
#
#          ANIO_DENUNCIA  ANIO_ENTRADA  ANIO_HECHO       LEY      PAIS  ...  \
# 0                 2017          2017        2016   Ley 906  Colombia  ...
# 1                 2020          2020        2020   Ley 906  Colombia  ...
# 2                 2020          2020        2020   Ley 906  Colombia  ...
# 3                 2017          2017        2017   Ley 906  Colombia  ...
# 4                 2011          2011        2011  Ley 1098  Colombia  ...
# ...                ...           ...         ...       ...       ...  ...
# 2062264           2013          2013        2013   Ley 906  Colombia  ...
# 2062265           2017          2017        2017   Ley 906  Colombia  ...
# 2062266           2020          2020        2020   Ley 906  Colombia  ...
# 2062267           2020          2020        2020   Ley 906  Colombia  ...
# 2062268           2016          2016        2016   Ley 906  Colombia  ...
#
#                                                  SECCIONAL  \
# 0                      DIRECCIÓN SECCIONAL DE CUNDINAMARCA
# 1                            DIRECCIÓN SECCIONAL DE BOGOTÁ
# 2                            DIRECCIÓN SECCIONAL DE BOGOTÁ
# 3        DIRECCION ESPECIALIZADA CONTRA ORGANIZACIONES ...
# 4                          DIRECCIÓN SECCIONAL DE MEDELLÍN
# ...                                                    ...
# 2062264                    DIRECCIÓN SECCIONAL DE GUAVIARE
# 2062265                      DIRECCIÓN SECCIONAL DE TOLIMA
# 2062266             DIRECCIÓN SECCIONAL DE VALLE DEL CAUCA
# 2062267             DIRECCIÓN SECCIONAL DE MAGDALENA MEDIO
# 2062268                     DIRECCIÓN SECCIONAL DE CÓRDOBA
#
#                          GRUPO_DELITO  \
# 0               FALSEDAD EN DOCUMENTO
# 1                               HURTO
# 2                               HURTO
# 3                     ESTUPEFACIENTES
# 4                   SEGURIDAD PUBLICA
# ...                               ...
# 2062264    VIDA E INTEGRIDAD PERSONAL
# 2062265  LESIONES PERSONALES CULPOSAS
# 2062266                         HURTO
# 2062267        ADMINISTRACION PUBLICA
# 2062268           DELITOS AMBIENTALES
#
#                                                     DELITO CAPTURA IMPUTACION  \
# 0        FALSEDAD IDEOLOGICA EN DOCUMENTO PUBLICO. ART....      NO         NO
# 1        HURTO. ART. 239 C.P. AGRAVADO CUANDO LO HURTAD...      NO         NO
# 2        HURTO CALIFICADO MENOR CUANTIA ART. 240 C.P.  ...      NO         SI
# 3        TRAFICO FABRICACION O PORTE DE ESTUPEFACIENTES...      SI         SI
# 4        OBSTRUCCION A VIAS PUBLICAS QUE AFECTAN EL ORD...      NO         NO
# ...                                                    ...     ...        ...
# 2062264    DELITOS CONTRA LA VIDA Y LA INTEGRIDAD PERSONAL      NO         NO
# 2062265           LESIONES CULPOSAS ART. 120 C.P. INCISO 1      NO         NO
# 2062266  HURTO CALIFICADO ART. 240 C.P.  AGRAVADO CUAND...      NO         NO
# 2062267  ABUSO DE AUTORIDAD POR ACTO ARBITRARIO O INJUS...      NO         NO
# 2062268  DE LOS DELITOS CONTRA LOS RECURSOS NATURALES Y...      NO         NO
#
#         CONDENA ATIPICIDAD_INEXISTENCIA ACUSACION HOMICIDIO_DOLOSO_CONSUMADO  \
# 0            NO                      NO        NO                         NO
# 1            NO                      NO        NO                         NO
# 2            NO                      NO        NO                         NO
# 3            SI                      NO        SI                         NO
# 4            NO                      NO        NO                         NO
# ...         ...                     ...       ...                        ...
# 2062264      NO                      SI        NO                         NO
# 2062265      NO                      NO        NO                         NO
# 2062266      NO                      NO        NO                         NO
# 2062267      NO                      NO        NO                         NO
# 2062268      NO                      SI        NO                         NO
#
#         TOTAL_PROCESOS
# 0                    1
# 1                  891
# 2                  284
# 3                    1
# 4                    1
# ...                ...
# 2062264              1
# 2062265              1
# 2062266              1
# 2062267              1
# 2062268              1
#
# [2062269 rows x 22 columns]

# %%
print('Base')
print('Filas: ', Base.shape[0])
print('Columnas: ', Base.shape[1])
# Out:
# Base
# Filas:  2062369
# Columnas:  22

# %% [markdown]
# Acontinuación se mostraran los atributos y tipos de atributo.

# %%
Base.dtypes
# Out:
# HECHO                         object
# RUPTURA                       object
# CONEXO                        object
# ESTADO_NOTICIA                object
# ETAPA                         object
# ANIO_DENUNCIA                  int64
# ANIO_ENTRADA                   int64
# ANIO_HECHO                     int64
# LEY                           object
# PAIS                          object
# DEPARTAMENTO                  object
# MUNICIPIO                     object
# SECCIONAL                     object
# GRUPO_DELITO                  object
# DELITO                        object
# CAPTURA                       object
# IMPUTACION                    object
# CONDENA                       object
# ATIPICIDAD_INEXISTENCIA       object
# ACUSACION                     object
# HOMICIDIO_DOLOSO_CONSUMADO    object
# TOTAL_PROCESOS                 int64
# dtype: object

# %% [markdown]
# ## Completitud

# %% [markdown]
# Para la limpieza de datos lo primero que se hizo fue saber donde habian datos nulos o faltantes y cual era el porcentaje de estos.

# %%
#Saber donde hay nulos
Base.isnull()
# Out:
#          HECHO  RUPTURA  CONEXO  ESTADO_NOTICIA  ETAPA  ANIO_DENUNCIA  \
# 0        False    False   False           False  False          False
# 1        False    False   False           False  False          False
# 2        False    False   False           False  False          False
# 3        False    False   False           False  False          False
# 4        False    False   False           False  False          False
# ...        ...      ...     ...             ...    ...            ...
# 2062364  False    False   False           False  False          False
# 2062365  False    False   False           False  False          False
# 2062366  False    False   False           False  False          False
# 2062367  False    False   False           False  False          False
# 2062368  False    False   False           False  False          False
#
#          ANIO_ENTRADA  ANIO_HECHO    LEY   PAIS  ...  SECCIONAL  GRUPO_DELITO  \
# 0               False       False  False  False  ...      False         False
# 1               False       False  False  False  ...      False         False
# 2               False       False  False  False  ...      False         False
# 3               False       False  False  False  ...      False         False
# 4               False       False  False  False  ...      False         False
# ...               ...         ...    ...    ...  ...        ...           ...
# 2062364         False       False  False  False  ...      False         False
# 2062365         False       False  False  False  ...      False         False
# 2062366         False       False  False  False  ...      False         False
# 2062367         False       False  False  False  ...      False         False
# 2062368         False       False  False  False  ...      False         False
#
#          DELITO  CAPTURA  IMPUTACION  CONDENA  ATIPICIDAD_INEXISTENCIA  \
# 0         False    False       False    False                    False
# 1         False    False       False    False                    False
# 2         False    False       False    False                    False
# 3         False    False       False    False                    False
# 4         False    False       False    False                    False
# ...         ...      ...         ...      ...                      ...
# 2062364   False    False       False    False                    False
# 2062365   False    False       False    False                    False
# 2062366   False    False       False    False                    False
# 2062367   False    False       False    False                    False
# 2062368   False    False       False    False                    False
#
#          ACUSACION  HOMICIDIO_DOLOSO_CONSUMADO  TOTAL_PROCESOS
# 0            False                       False           False
# 1            False                       False           False
# 2            False                       False           False
# 3            False                       False           False
# 4            False                       False           False
# ...            ...                         ...             ...
# 2062364      False                       False           False
# 2062365      False                       False           False
# 2062366      False                       False           False
# 2062367      False                       False           False
# 2062368      False                       False           False
#
# [2062369 rows x 22 columns]

# %%
for col in Base.columns:
    num_missing = Base[col].isnull().sum()
    pct_missing = np.mean(Base[col].isnull())
    #print(col," - ",round(pct_missing*100, 2),"% - ",num_missing)
    print('{} - {}% - {}'.format(col,round(pct_missing*100, 7),num_missing))
# Out:
# HECHO - 0.0% - 0
# RUPTURA - 0.0% - 0
# CONEXO - 0.0% - 0
# ESTADO_NOTICIA - 4.85e-05% - 1
# ETAPA - 0.001988% - 41
# ANIO_DENUNCIA - 0.0% - 0
# ANIO_ENTRADA - 0.0% - 0
# ANIO_HECHO - 0.0% - 0
# LEY - 0.0% - 0
# PAIS - 0.0008728% - 18
# DEPARTAMENTO - 0.0008728% - 18
# MUNICIPIO - 0.0008728% - 18
# SECCIONAL - 0.7231005% - 14913
# GRUPO_DELITO - 0.0% - 0
# DELITO - 0.0% - 0
# CAPTURA - 0.0% - 0
# IMPUTACION - 0.0% - 0
# CONDENA - 0.0% - 0
# ATIPICIDAD_INEXISTENCIA - 0.0% - 0
# ACUSACION - 0.0% - 0
# HOMICIDIO_DOLOSO_CONSUMADO - 0.0% - 0
# TOTAL_PROCESOS - 0.0% - 0

# %% [markdown]
# Como se evidencia las variable Seccional es la que más contiene datos perdidos. A continuación se hara una visualización de esos datos perdidos

# %%
Base[Base["ESTADO_NOTICIA"].isnull() == True]
# Out:
#        HECHO RUPTURA CONEXO ESTADO_NOTICIA       ETAPA  ANIO_DENUNCIA  \
# 949355    SI      NO     NO            NaN  INDAGACIÓN           2020
#
#         ANIO_ENTRADA  ANIO_HECHO      LEY      PAIS  ...  \
# 949355          2020        2020  Ley 906  Colombia  ...
#
#                             SECCIONAL           GRUPO_DELITO  \
# 949355  DIRECCIÓN SECCIONAL DE BOGOTÁ  FALSEDAD EN DOCUMENTO
#
#                                               DELITO CAPTURA IMPUTACION  \
# 949355  FALSEDAD EN DOCUMENTO PRIVADO. ART. 289 C.P.      NO         NO
#
#        CONDENA ATIPICIDAD_INEXISTENCIA ACUSACION HOMICIDIO_DOLOSO_CONSUMADO  \
# 949355      NO                      NO        NO                         NO
#
#        TOTAL_PROCESOS
# 949355              1
#
# [1 rows x 22 columns]

# %% [markdown]
# +  *ESTADO_NOTICIA:*
# Se evidencia que el dato 949355 es el faltante para la variable estado de notici.

# %%
Base[Base["ETAPA"].isnull() == True]
# Out:
#         HECHO RUPTURA CONEXO ESTADO_NOTICIA ETAPA  ANIO_DENUNCIA  \
# 84424      SI      NO     NO       INACTIVO   NaN           2010
# 102455     SI      NO     NO       INACTIVO   NaN           2011
# 127536     NO      SI     NO         ACTIVO   NaN           2012
# 200711     SI      NO     NO       INACTIVO   NaN           2013
# 205953     SI      NO     NO       INACTIVO   NaN           2013
# 245402     NO      SI     NO         ACTIVO   NaN           2012
# 310647     SI      NO     NO       INACTIVO   NaN           2012
# 334230     SI      NO     NO       INACTIVO   NaN           2013
# 384481     SI      NO     NO       INACTIVO   NaN           2014
# 391821     SI      NO     NO       INACTIVO   NaN           2010
# 627579     SI      NO     NO       INACTIVO   NaN           2014
# 691385     SI      NO     NO       INACTIVO   NaN           2013
# 838466     SI      NO     NO         ACTIVO   NaN           2012
# 839591     SI      NO     NO       INACTIVO   NaN           2012
# 865688     SI      NO     NO       INACTIVO   NaN           2012
# 924528     SI      NO     NO       INACTIVO   NaN           2012
# 1011756    NO      SI     NO         ACTIVO   NaN           2012
# 1038219    SI      NO     NO         ACTIVO   NaN           2014
# 1038899    SI      NO     NO         ACTIVO   NaN           2012
# 1051831    NO      NO     NO       INACTIVO   NaN           2014
# 1063134    SI      NO     NO       INACTIVO   NaN           2014
# 1115812    SI      NO     NO         ACTIVO   NaN           2011
# 1161502    SI      NO     NO       INACTIVO   NaN           2013
# 1257188    SI      NO     NO       INACTIVO   NaN           2011
# 1278198    SI      NO     NO       INACTIVO   NaN           2014
# 1288484    SI      NO     NO       INACTIVO   NaN           2013
# 1323599    NO      SI     NO       INACTIVO   NaN           2010
# 1418180    SI      NO     NO         ACTIVO   NaN           2013
# 1497258    NO      SI     NO         ACTIVO   NaN           2012
# 1528299    SI      NO     NO       INACTIVO   NaN           2011
# 1602626    SI      NO     NO       INACTIVO   NaN           2013
# 1608215    NO      SI     NO       INACTIVO   NaN           2010
# 1640993    SI      NO     NO         ACTIVO   NaN           2011
# 1647470    NO      SI     NO         ACTIVO   NaN           2013
# 1697733    SI      NO     NO       INACTIVO   NaN           2012
# 1712485    SI      NO     NO       INACTIVO   NaN           2014
# 1728373    SI      NO     NO       INACTIVO   NaN           2014
# 1759454    SI      NO     NO       INACTIVO   NaN           2010
# 1788402    SI      NO     NO       INACTIVO   NaN           2010
# 1922532    SI      NO     NO       INACTIVO   NaN           2014
# 1976950    NO      SI     NO       INACTIVO   NaN           2010
#
#          ANIO_ENTRADA  ANIO_HECHO      LEY      PAIS  ...  \
# 84424            2010        2010  Ley 906  Colombia  ...
# 102455           2011        2011  Ley 906  Colombia  ...
# 127536           2012        2012  Ley 906  Colombia  ...
# 200711           2013        2013  Ley 906  Colombia  ...
# 998966              INASISTENCIA ALIMENTARIA ART. 233 C.P.      NO         NO
# 1031335               CONSTREÑIMIENTO ILEGAL ART. 182 C.P.      NO         NO
# 1084526  ACCESO ABUSIVO A UN SISTEMA INFORMATICO ART 26...      NO         NO
# 1178265                             INJURIA. ART. 220 C.P.      NO         NO
# 1537711  ESTAFA. ART. 246 C.P. AGRAVADA CUANDO LA ESTAF...      NO         NO
# 1572194                   FALSEDAD PERSONAL. ART. 296 C.P.      NO         NO
# 1663559  ACCESO ABUSIVO A UN SISTEMA INFORMATICO ART 26...      NO         NO
# 1670169                              ESTAFA. ART. 246 C.P.      NO         NO
# 1862778                             AMENAZAS ART. 347 C.P.      NO         NO
# 1875666  HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES ART...      NO         NO
# 2042340            INJURIA POR VIAS DE HECHO ART. 226 C.P.      NO         NO
#
#         CONDENA ATIPICIDAD_INEXISTENCIA ACUSACION HOMICIDIO_DOLOSO_CONSUMADO  \
# 81530        NO                      SI        NO                         NO
# 130777       NO                      SI        NO                         NO
# 225343       NO                      NO        NO                         NO
# 248350       NO                      SI        NO                         NO
# 465343       NO                      SI        NO                         NO
# 751188       NO                      NO        NO                         NO
# 835801       NO                      SI        NO                         NO
# 998966       NO                      SI        NO                         NO
# 1031335      NO                      SI        NO                         NO
# 1084526      NO                      NO        NO                         NO
# 1178265      NO                      NO        NO                         NO
# 1537711      NO                      NO        NO                         NO
# 1572194      NO                      NO        NO                         NO
# 1663559      NO                      NO        NO                         NO
# 1670169      NO                      SI        NO                         NO
# 1862778      NO                      SI        NO                         NO
# 1875666      NO                      NO        NO                         NO
# 2042340      NO                      NO        NO                         NO
#
#         TOTAL_PROCESOS
# 81530                3
# 130777               2
# 225343               1
# 248350               1
# 465343               1
# 751188               3
# 835801               1
# 998966               1
# 1031335              4
# 1084526              1
# 1178265              1
# 1537711              1
# 1572194              4
# 1663559              2
# 1670169              4
# 1862778              9
# 1875666              1
# 2042340              2
#
# [18 rows x 22 columns]

# %% [markdown]
# +  *DEPARTAMENTO:*
# Para la variable departamento se evidenciaron  18  datos  faltantes las cuales coindicen con las filas de las variables departamento, pais y municipio.

# %%
Base[Base["SECCIONAL"].isnull() == True]
# Out:
#         HECHO RUPTURA CONEXO ESTADO_NOTICIA        ETAPA  ANIO_DENUNCIA  \
# 100        SI      NO     NO       INACTIVO  QUERELLABLE           2010
# 732        SI      NO     NO       INACTIVO   INDAGACIÓN           2012
# 1200       SI      NO     NO       INACTIVO   INDAGACIÓN           2017
# 1308       SI      NO     NO       INACTIVO   INDAGACIÓN           2012
# 1309       SI      NO     NO       INACTIVO   INDAGACIÓN           2013
# ...       ...     ...    ...            ...          ...            ...
# 2061571    NO      NO     NO       INACTIVO  QUERELLABLE           2010
# 2061972    SI      NO     NO       INACTIVO   INDAGACIÓN           2012
# 2062143    SI      NO     NO       INACTIVO  QUERELLABLE           2011
# 2062149    SI      NO     NO       INACTIVO   INDAGACIÓN           2014
# 2062199    SI      NO     NO       INACTIVO   INDAGACIÓN           2015
#
#          ANIO_ENTRADA  ANIO_HECHO       LEY      PAIS  ... SECCIONAL  \
# 100              2010        2010   Ley 906  Colombia  ...       NaN
# 732              2012        2012   Ley 906  Colombia  ...       NaN
# 1200             2017        2016   Ley 906  Colombia  ...       NaN
# 1308             2012        2012   Ley 906  Colombia  ...       NaN
# 1309             2013        2013   Ley 906  Colombia  ...       NaN
# ...               ...         ...       ...       ...  ...       ...
# 2061571          2010        2010   Ley 906  Colombia  ...       NaN
# 2061972          2012        2011   Ley 906  Colombia  ...       NaN
# 2062143          2011        2011   Ley 906  Colombia  ...       NaN
# 2062149          2014        2014   Ley 906  Colombia  ...       NaN
# 2062199          2015        2014  Ley 1098  Colombia  ...       NaN
#
#                   GRUPO_DELITO  \
# 100         INJURIA Y CALUMNIA
# 732                      HURTO
# 1200                     HURTO
# 1308           ESTUPEFACIENTES
# 1309          HOMICIDIO DOLOSO
# ...                        ...
# 2061571                 ESTAFA
# 2061972   DELITOS INFORMATICOS
# 2062143       HOMICIDIO DOLOSO
# 2062149  FALSEDAD EN DOCUMENTO
# 2062199       DELITOS SEXUALES
#
#                                                     DELITO CAPTURA IMPUTACION  \
# 100                            DE LA INJURIA Y LA CALUMNIA      NO         NO
# 732                                   HURTO. ART. 239 C.P.      NO         NO
# 1200                                  HURTO. ART. 239 C.P.      NO         NO
# 1308     TRAFICO FABRICACION O PORTE DE ESTUPEFACIENTES...      SI         NO
# 1309                               HOMICIDIO ART. 103 C.P.      NO         NO
# ...                                                    ...     ...        ...
# 2061571                ESTAFA. ART. 246 C.P. MENOR CUANTIA      NO         NO
# 2061972  HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES ART...      NO         NO
# 2062143                            HOMICIDIO ART. 103 C.P.      NO         NO
# 2062149  FALSEDAD MATERIAL EN DOCUMENTO PUBLICO. ART. 2...      NO         NO
# 2062199  ACTOS SEXUALES CON MENOR DE CATORCE AÑOS. ART....      NO         NO
#
#         CONDENA ATIPICIDAD_INEXISTENCIA ACUSACION HOMICIDIO_DOLOSO_CONSUMADO  \
# 100          NO                      NO        NO                         NO
# 732          NO                      NO        NO                         NO
# 1200         NO                      NO        NO                         NO
# 1308         NO                      NO        NO                         NO
# 1309         NO                      NO        NO                         SI
# ...         ...                     ...       ...                        ...
# 2061571      NO                      SI        NO                         NO
# 2061972      NO                      NO        NO                         NO
# 2062143      NO                      NO        NO                         NO
# 2062149      NO                      NO        NO                         NO
# 2062199      NO                      NO        NO                         NO
#
#         TOTAL_PROCESOS
# 100                  1
# 732                  1
# 1200                 4
# 1308                 1
# 1309                 1
# ...                ...
# 2061571              1
# 2061972              1
# 2062143              1
# 2062149              1
# 2062199              1
#
# [14913 rows x 22 columns]

# %% [markdown]
# +  *SECCIONAL:*
# La variable seccional tiene el 14913 datos perdidos, lo cual corresponde al 0.72% de la muestra y es la que más contiene.

# %% [markdown]
# ### Seleccionar columnas que se usarán para el análisis

# %% [markdown]
# Se seleccionaron las siguientes variables, las cuales se utilizaran en el análisis. Pero basados en los porcentajes de faltantes lo primero que se hara sera borrar los registros ya que la cantida de datos que se elimina no es significativa y si se imputan se podría sesgar la base, la variable ATIPICIDAD_INEXISTENCIA no fue utilizada puesto que conceptualmente no es muy entendible su interpretacion.

# %%
columns = ['HECHO',
          'RUPTURA',
          'CONEXO',
          'ESTADO_NOTICIA',
          'ETAPA',
          'ANIO_DENUNCIA',
           'ANIO_ENTRADA',
           'ANIO_HECHO',
           'LEY',
           'PAIS',
           'DEPARTAMENTO',
           'MUNICIPIO',
           'SECCIONAL',
           'GRUPO_DELITO',
           'DELITO',
           'CAPTURA',
           'IMPUTACION',
           'CONDENA',
           'ACUSACION',
           'HOMICIDIO_DOLOSO_CONSUMADO',
           'TOTAL_PROCESOS']
Base1 = Base.copy()
Base1 = Base[columns]
Base1
# Out:
#         HECHO RUPTURA CONEXO ESTADO_NOTICIA               ETAPA  \
# 0          SI      NO     NO         ACTIVO          INDAGACIÓN
# 1          SI      NO     NO         ACTIVO          INDAGACIÓN
# 2          SI      NO     NO         ACTIVO              JUICIO
# 3          SI      NO     NO       INACTIVO  EJECUCIÓN DE PENAS
# 4          SI      NO     NO       INACTIVO          INDAGACIÓN
# ...       ...     ...    ...            ...                 ...
# 2062364    SI      NO     NO       INACTIVO         QUERELLABLE
# 2062365    SI      NO     NO       INACTIVO          INDAGACIÓN
# 2062366    SI      NO     NO       INACTIVO         QUERELLABLE
# 2062367    SI      NO     NO         ACTIVO          INDAGACIÓN
# 2062368    SI      NO     NO       INACTIVO  EJECUCIÓN DE PENAS
#
#          ANIO_DENUNCIA  ANIO_ENTRADA  ANIO_HECHO       LEY      PAIS  ...  \
# 0                 2017          2017        2016   Ley 906  Colombia  ...
# 1                 2020          2020        2020   Ley 906  Colombia  ...
# 2                 2020          2020        2020   Ley 906  Colombia  ...
# 3                 2017          2017        2017   Ley 906  Colombia  ...
# 4                 2011          2011        2011  Ley 1098  Colombia  ...
# ...                ...           ...         ...       ...       ...  ...
# 2062364           2012          2012        2011   Ley 906  Colombia  ...
# 2062365           2018          2018        2018  Ley 1098  Colombia  ...
# 2062366           2015          2015        2015   Ley 906  Colombia  ...
# 2062367           2020          2020        2020   Ley 906  Colombia  ...
# 2062368           2011          2011        2011   Ley 906  Colombia  ...
#
#             MUNICIPIO                                          SECCIONAL  \
# 0          FACATATIVÁ                DIRECCIÓN SECCIONAL DE CUNDINAMARCA
# 1        BOGOTÁ, D.C.                      DIRECCIÓN SECCIONAL DE BOGOTÁ
# 2        BOGOTÁ, D.C.                      DIRECCIÓN SECCIONAL DE BOGOTÁ
# 3            LA PLATA  DIRECCION ESPECIALIZADA CONTRA ORGANIZACIONES ...
# 4            MEDELLÍN                    DIRECCIÓN SECCIONAL DE MEDELLÍN
# ...               ...                                                ...
# 2062364     BARBACOAS                      DIRECCIÓN SECCIONAL DE NARIÑO
# 2062365  BOGOTÁ, D.C.                      DIRECCIÓN SECCIONAL DE BOGOTÁ
# 2062366        ABREGO          DIRECCIÓN SECCIONAL DE NORTE DE SANTANDER
# 2062367   PUEBLOVIEJO                   DIRECCIÓN SECCIONAL DE MAGDALENA
# 2062368       AGUADAS                      DIRECCIÓN SECCIONAL DE CALDAS
#
#                      GRUPO_DELITO  \
# 0           FALSEDAD EN DOCUMENTO
# 1                           HURTO
# 2                           HURTO
# 3                 ESTUPEFACIENTES
# 4               SEGURIDAD PUBLICA
# ...                           ...
# 2062364       LESIONES PERSONALES
# 2062365                     HURTO
# 2062366       LESIONES PERSONALES
# 2062367  CONCIERTO PARA DELINQUIR
# 2062368       LESIONES PERSONALES
#
#                                                     DELITO CAPTURA IMPUTACION  \
# 0        FALSEDAD IDEOLOGICA EN DOCUMENTO PUBLICO. ART....      NO         NO
# 1        HURTO. ART. 239 C.P. AGRAVADO CUANDO LO HURTAD...      NO         NO
# 2        HURTO CALIFICADO MENOR CUANTIA ART. 240 C.P.  ...      NO         SI
# 3        TRAFICO FABRICACION O PORTE DE ESTUPEFACIENTES...      SI         SI
# 4        OBSTRUCCION A VIAS PUBLICAS QUE AFECTAN EL ORD...      NO         NO
# ...                                                    ...     ...        ...
# 2062364  LESIONES PERSONALES CON INCAPACIDAD MENOR 60 DIAS      NO         NO
# 2062365  HURTO CALIFICADO ART. 240 C.P. AGRAVADO POR LA...      NO         NO
# 2062366  LESIONES PERSONALES CON INCAPACIDAD MENOR 60 DIAS      NO         NO
# 2062367             CONCIERTO PARA DELINQUIR ART. 340 C.P.      NO         NO
# 2062368                             LESIONES ART. 111 C.P.      NO         SI
#
#         CONDENA ACUSACION HOMICIDIO_DOLOSO_CONSUMADO TOTAL_PROCESOS
# 0            NO        NO                         NO              1
# 1            NO        NO                         NO            891
# 2            NO        NO                         NO            284
# 3            SI        SI                         NO              1
# 4            NO        NO                         NO              1
# ...         ...       ...                        ...            ...
# 2062364      NO        NO                         NO              1
# 2062365      NO        NO                         NO              1
# 2062366      NO        NO                         NO              1
# 2062367      NO        NO                         NO              1
# 2062368      NO        NO                         NO              1
#
# [2062369 rows x 21 columns]

# %%
print('Antes de borrar registros: ',Base1.shape)
for col in Base1.columns:
    missing = Base1[col].isnull()
    num_missing = np.sum(missing)
    
    if num_missing > 0:  
        print('created missing indicator for: {}'.format(col))
        Base1['{}_ismissing'.format(col)] = missing
ismissing_cols = [col for col in Base1.columns if 'ismissing' in col]
Base1['num_missing'] = Base1[ismissing_cols].sum(axis=1)
# Out:
# Antes de borrar registros:  (2062369, 21)
# created missing indicator for: ESTADO_NOTICIA
# created missing indicator for: ETAPA
# created missing indicator for: PAIS
# created missing indicator for: DEPARTAMENTO
# created missing indicator for: MUNICIPIO
# created missing indicator for: SECCIONAL

# %%
Base1[Base1.num_missing >= 1]
# Out:
#         HECHO RUPTURA CONEXO ESTADO_NOTICIA        ETAPA  ANIO_DENUNCIA  \
# 100        SI      NO     NO       INACTIVO  QUERELLABLE           2010
# 732        SI      NO     NO       INACTIVO   INDAGACIÓN           2012
# 1200       SI      NO     NO       INACTIVO   INDAGACIÓN           2017
# 1308       SI      NO     NO       INACTIVO   INDAGACIÓN           2012
# 1309       SI      NO     NO       INACTIVO   INDAGACIÓN           2013
# ...       ...     ...    ...            ...          ...            ...
# 2061571    NO      NO     NO       INACTIVO  QUERELLABLE           2010
# 2061972    SI      NO     NO       INACTIVO   INDAGACIÓN           2012
# 2062143    SI      NO     NO       INACTIVO  QUERELLABLE           2011
# 2062149    SI      NO     NO       INACTIVO   INDAGACIÓN           2014
# 2062199    SI      NO     NO       INACTIVO   INDAGACIÓN           2015
#
#          ANIO_ENTRADA  ANIO_HECHO       LEY      PAIS  ... ACUSACION  \
# 100              2010        2010   Ley 906  Colombia  ...        NO
# 732              2012        2012   Ley 906  Colombia  ...        NO
# 1200             2017        2016   Ley 906  Colombia  ...        NO
# 1308             2012        2012   Ley 906  Colombia  ...        NO
# 1309             2013        2013   Ley 906  Colombia  ...        NO
# ...               ...         ...       ...       ...  ...       ...
# 2061571          2010        2010   Ley 906  Colombia  ...        NO
# 2061972          2012        2011   Ley 906  Colombia  ...        NO
# 2062143          2011        2011   Ley 906  Colombia  ...        NO
# 2062149          2014        2014   Ley 906  Colombia  ...        NO
# 2062199          2015        2014  Ley 1098  Colombia  ...        NO
#
#         HOMICIDIO_DOLOSO_CONSUMADO TOTAL_PROCESOS ESTADO_NOTICIA_ismissing  \
# 100                             NO              1                    False
# 732                             NO              1                    False
# 1200                            NO              4                    False
# 1308                            NO              1                    False
# 1309                            SI              1                    False
# ...                            ...            ...                      ...
# 2061571                         NO              1                    False
# 2061972                         NO              1                    False
# 2062143                         NO              1                    False
# 2062149                         NO              1                    False
# 2062199                         NO              1                    False
#
#         ETAPA_ismissing PAIS_ismissing DEPARTAMENTO_ismissing  \
# 100               False          False                  False
# 732               False          False                  False
# 1200              False          False                  False
# 1308              False          False                  False
# 1309              False          False                  False
# ...                 ...            ...                    ...
# 2061571           False          False                  False
# 2061972           False          False                  False
# 2062143           False          False                  False
# 2062149           False          False                  False
# 2062199           False          False                  False
#
#         MUNICIPIO_ismissing SECCIONAL_ismissing num_missing
# 100                   False                True           1
# 732                   False                True           1
# 1200                  False                True           1
# 1308                  False                True           1
# 1309                  False                True           1
# ...                     ...                 ...         ...
# 2061571               False                True           1
# 2061972               False                True           1
# 2062143               False                True           1
# 2062149               False                True           1
# 2062199               False                True           1
#
# [14973 rows x 28 columns]

# %%
ind_missing = Base1[Base1['num_missing'] >= 1].index
df_less_missing_rows = Base1.drop(ind_missing, axis=0)
df_less_missing_rows = df_less_missing_rows[columns]
print('Después de borrar registros: ',df_less_missing_rows.shape)
# Out:
# Después de borrar registros:  (2047396, 21)

# %%
for col in Base1.columns:
    num_missing = Base1[col].isnull().sum()  
    pct_missing = np.mean(Base1[col].isnull())
    #print(col," - ",round(pct_missing*100, 2),"% - ",num_missing)
    print('{} - {}% - {}'.format(col,round(pct_missing*100, 2),num_missing))
# Out:
# HECHO - 0.0% - 0
# RUPTURA - 0.0% - 0
# CONEXO - 0.0% - 0
# ESTADO_NOTICIA - 0.0% - 1
# ETAPA - 0.0% - 41
# ANIO_DENUNCIA - 0.0% - 0
# ANIO_ENTRADA - 0.0% - 0
# ANIO_HECHO - 0.0% - 0
# LEY - 0.0% - 0
# PAIS - 0.0% - 18
# DEPARTAMENTO - 0.0% - 18
# MUNICIPIO - 0.0% - 18
# SECCIONAL - 0.72% - 14913
# GRUPO_DELITO - 0.0% - 0
# DELITO - 0.0% - 0
# CAPTURA - 0.0% - 0
# IMPUTACION - 0.0% - 0
# CONDENA - 0.0% - 0
# ACUSACION - 0.0% - 0
# HOMICIDIO_DOLOSO_CONSUMADO - 0.0% - 0
# TOTAL_PROCESOS - 0.0% - 0
# ESTADO_NOTICIA_ismissing - 0.0% - 0
# ETAPA_ismissing - 0.0% - 0
# PAIS_ismissing - 0.0% - 0
# DEPARTAMENTO_ismissing - 0.0% - 0
# MUNICIPIO_ismissing - 0.0% - 0
# SECCIONAL_ismissing - 0.0% - 0
# num_missing - 0.0% - 0

# %% [markdown]
# Al borrar los registros faltantes se observa que no hay ningun dato perdido y la base quedo con un total de 2'047.396 filas y 21 columnas. Pero, se verificará que dentro de esta nueva base no haya datos duplicados.

# %% [markdown]
# ## Coherencia

# %% [markdown]
# DUPLICADOS

# %%
Base1 = df_less_missing_rows
Base1[Base1.duplicated()]
# Out:
#         HECHO RUPTURA CONEXO ESTADO_NOTICIA          ETAPA  ANIO_DENUNCIA  \
# 119255     NO      SI     NO       INACTIVO  INVESTIGACIÓN           2014
# 190456     NO      SI     NO       INACTIVO         JUICIO           2015
# 209363     NO      SI     NO       INACTIVO  INVESTIGACIÓN           2016
# 237980     NO      SI     NO       INACTIVO  INVESTIGACIÓN           2018
# 276155     NO      SI     NO       INACTIVO         JUICIO           2011
# ...       ...     ...    ...            ...            ...            ...
# 2035708    NO      SI     NO       INACTIVO     INDAGACIÓN           2020
# 2036508    NO      SI     NO       INACTIVO  INVESTIGACIÓN           2015
# 2036630    NO      SI     NO       INACTIVO         JUICIO           2015
# 2040955    NO      SI     NO       INACTIVO  INVESTIGACIÓN           2013
# 2045048    NO      SI     NO       INACTIVO         JUICIO           2016
#
#          ANIO_ENTRADA  ANIO_HECHO       LEY      PAIS  ...  \
# 119255           2017        2014   Ley 906  Colombia  ...
# 190456           2016        2015   Ley 906  Colombia  ...
# 209363           2016        2016   Ley 906  Colombia  ...
# 237980           2019        2018   Ley 906  Colombia  ...
# 276155           2011        2011   Ley 906  Colombia  ...
# ...               ...         ...       ...       ...  ...
# 2035708          2020        2020  Ley 1098  Colombia  ...
# 2036508          2015        2015   Ley 906  Colombia  ...
# 2036630          2016        2015   Ley 906  Colombia  ...
# 2040955          2013        2013   Ley 906  Colombia  ...
# 2045048          2018        2016   Ley 906  Colombia  ...
#
#                       MUNICIPIO  \
# 119255                   SOACHA
# 190456              BUCARAMANGA
# 209363                   CALOTO
# 237980              SANTA MARTA
# 276155              BUCARAMANGA
# ...                         ...
# 2035708            BOGOTÁ, D.C.
# 2036508  SANTANDER DE QUILICHAO
# 2036630             BUCARAMANGA
# 2040955                    CALI
# 2045048             PUERTO ASÍS
#
#                                                  SECCIONAL  \
# 119255                 DIRECCIÓN SECCIONAL DE CUNDINAMARCA
# 190456                    DIRECCIÓN SECCIONAL DE SANTANDER
# 209363                        DIRECCIÓN SECCIONAL DE CAUCA
# 237980                    DIRECCIÓN SECCIONAL DE MAGDALENA
# 276155                    DIRECCIÓN SECCIONAL DE SANTANDER
# ...                                                    ...
# 2035708                      DIRECCIÓN SECCIONAL DE BOGOTÁ
# 2036508                       DIRECCIÓN SECCIONAL DE CAUCA
# 2036630                   DIRECCIÓN SECCIONAL DE SANTANDER
# 2040955                        DIRECCIÓN SECCIONAL DE CALI
# 2045048  DIRECCION ESPECIALIZADA CONTRA ORGANIZACIONES ...
#
#                                   GRUPO_DELITO  \
# 119255                         ESTUPEFACIENTES
# 190456                                   HURTO
# 209363                         ESTUPEFACIENTES
# 237980   FABRICACION, TRAFICO Y PORTE DE ARMAS
# 276155                         ESTUPEFACIENTES
# ...                                        ...
# 2035708                        ESTUPEFACIENTES
# 2036508                        ESTUPEFACIENTES
# 2036630                        ESTUPEFACIENTES
# 2040955                    LESIONES PERSONALES
# 2045048                        ESTUPEFACIENTES
#
#                                                     DELITO CAPTURA IMPUTACION  \
# 119255   TRAFICO FABRICACION O PORTE DE ESTUPEFACIENTES...      NO         NO
# 190456          HURTO AGRAVADO ART. 239 C.P. MENOR CUANTIA      SI         SI
# 209363   TRAFICO FABRICACION O PORTE DE ESTUPEFACIENTES...      SI         SI
# 237980   FABRICACION, TRAFICO Y PORTE DE ARMAS DE FUEGO...      NO         NO
# 276155   TRAFICO FABRICACION O PORTE DE ESTUPEFACIENTES...      SI         SI
# ...                                                    ...     ...        ...
# 2035708  TRAFICO FABRICACION O PORTE DE ESTUPEFACIENTES...      NO         NO
# 2036508  TRAFICO FABRICACION O PORTE DE ESTUPEFACIENTES...      SI         NO
# 2036630  TRAFICO FABRICACION O PORTE DE ESTUPEFACIENTES...      SI         SI
# 2040955                             LESIONES ART. 111 C.P.      NO         NO
# 2045048  TRAFICO FABRICACION O PORTE DE ESTUPEFACIENTES...      NO         NO
#
#         CONDENA ACUSACION HOMICIDIO_DOLOSO_CONSUMADO TOTAL_PROCESOS
# 119255       NO        NO                         NO              1
# 190456       NO        SI                         NO              1
# 209363       NO        NO                         NO              1
# 237980       NO        NO                         NO              1
# 276155       NO        SI                         NO              1
# ...         ...       ...                        ...            ...
# 2035708      NO        NO                         NO              1
# 2036508      NO        NO                         NO              1
# 2036630      NO        SI                         NO              1
# 2040955      NO        NO                         NO              1
# 2045048      NO        NO                         NO              1
#
# [261 rows x 21 columns]

# %%
Base1 = Base1.drop_duplicates()
print(Base1.shape)
print(Base1.shape)
# Out:
# (2047135, 21)
# (2047135, 21)

# %% [markdown]
# Como se puede evidenciar si existían datos duplicados por lo cual se quitaron y se dejó la base limpia para trabajar.        La base tiene un problema con los años por lo cual hay que hacerle una transformación y verificar su consistencia lo cual consiste en cambiar el formato de la variable.

# %% [markdown]
# ### Consistencia

# %%
Base1.dtypes
# Out:
# HECHO                         object
# RUPTURA                       object
# CONEXO                        object
# ESTADO_NOTICIA                object
# ETAPA                         object
# ANIO_DENUNCIA                  int64
# ANIO_ENTRADA                   int64
# ANIO_HECHO                     int64
# LEY                           object
# PAIS                          object
# DEPARTAMENTO                  object
# MUNICIPIO                     object
# SECCIONAL                     object
# GRUPO_DELITO                  object
# DELITO                        object
# CAPTURA                       object
# IMPUTACION                    object
# CONDENA                       object
# ACUSACION                     object
# HOMICIDIO_DOLOSO_CONSUMADO    object
# TOTAL_PROCESOS                 int64
# dtype: object

# %% [markdown]
# #### Consistencia datos categóricos

# %%
Base1['ANIO_DENUNCIA'].value_counts()
# Out:
# 2018    222598
# 2017    218237
# 2019    211128
# 2016    202303
# 2015    194245
# 2014    185052
# 2013    179348
# 2012    169522
# 2020    161357
# 2011    155627
# 2010    119339
# 2021     28375
# 2005         4
# Name: ANIO_DENUNCIA, dtype: int64

# %%
Base1['ANIO_ENTRADA'].value_counts()
# Out:
# 2018    226160
# 2019    221026
# 2017    219558
# 2016    200867
# 2015    191409
# 2014    180607
# 2013    174002
# 2020    172864
# 2012    162029
# 2011    151736
# 2010    117249
# 2021     29622
# 2005         4
# 2009         2
# Name: ANIO_ENTRADA, dtype: int64

# %%
Base1['ANIO_HECHO'].value_counts()
# Out:
# 2017    207571
# 2018    204969
# 2016    197718
# 2015    194328
# 2014    189609
# 2013    186180
# 2012    184773
# 2019    182546
# 2011    182123
# 2010    169245
# 2020    131130
# 2021     16939
# 2055         3
# 2205         1
# Name: ANIO_HECHO, dtype: int64

# %% [markdown]
# Como se puede observar para la varaible año de hecho exiten dos años que aun no han pasado por lo cual se infiere que son errores de digitación.

# %%
Base1['ETAPA'].value_counts()
# Out:
# INDAGACIÓN                           1189954
# QUERELLABLE                           341403
# EJECUCIÓN DE PENAS                    226400
# JUICIO                                197500
# INVESTIGACIÓN                          82294
# TERMINACIÓN ANTICIPADA                  8169
# ETAPA DE INVESTIGACION PRELIMINAR       1243
# ETAPA DE INSTRUCCION                     172
# Name: ETAPA, dtype: int64

# %%
Base1['PAIS'].value_counts()
# Out:
# Colombia    2047135
# Name: PAIS, dtype: int64

# %%
Base1['LEY'].value_counts()
# Out:
# Ley 906                 1929026
# Ley 1098                 114414
# Jurisdicción Menores       2280
# LEY 600                    1415
# Name: LEY, dtype: int64

# %% [markdown]
# Visualmente el año de entrada y el año de denuncia son el mismo por lo cual se hará una resta para saber cuales son los diferentes, y así eliminarlos.

# %%
Desfase_A = Base1['ANIO_ENTRADA']- Base1['ANIO_DENUNCIA']

# %%
Desfase_A.value_counts()
# Out:
# 0 days        1970174
# 365 days        23188
# 730 days        11822
# 731 days         9304
# 1096 days        8159
# 366 days         6868
# 1461 days        6201
# 1095 days        3289
# 1826 days        2997
# 2191 days        1270
# 2557 days         863
# 2192 days         848
# 1827 days         767
# 2922 days         682
# 3287 days         323
# 2556 days         244
# 3652 days          75
# -365 days          25
# 3288 days          19
# 4018 days           8
# 3653 days           5
# -730 days           2
# -1461 days          1
# -1095 days          1
# dtype: int64

# %% [markdown]
# En este caso observamos que hay varios casos con muchos dias de diferencia.

# %% [markdown]
# #### Consistencia datos ordenados cuantitativos

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
Base1['TOTAL_PROCESOS'].describe()
# Out:
# count   2047135.00
# mean          6.37
# std         155.37
# min           1.00
# 25%           1.00
# 50%           1.00
# 75%           2.00
# max      116668.00
# Name: TOTAL_PROCESOS, dtype: float64

# %% [markdown]
# Con estas transformaciones echas la base de datos esta lista para trabajar en las visualizaciones.

# %% [markdown]
# ## Framework de las visualizaciones - María Alejandra Bolívar

# %% [markdown]
# Para  el primer modismo se seleccionaron las variables Estado de la noticia, municipio, total de procesos, etapa y delito las cuales en la ficha tecnica de la fiscalia general significan lo siguiente:
#
# 1. **Total procesos:**
# Conteo total de las noticias criminales al cruzar las variables anteriores.
#
# 2. **Estado de la noticia:**
# Estado de la noticia criminal al momento de la consulta del dato en el sistema de información: - Activo - Inactivo.
#
# 3. **Municipio:**
# Municipio en donde presuntamente ocurrieron los hechos que conoció la Fiscalía.
#
# 4. **Etapa:**
# Etapa procesal de la noticia criminal al momento de la consulta del dato en el sistema de información.
#
# 5. **Delito:**
# Delito basado en la escripción del artículo según el Código Penal
#
# 6. **Año de echo**
#
# 7. **Año de denuncia**
#
# 8. **imputación**

# %% [markdown]
# El modismo tiene como objetivo analizar y comparar cuantos procesos están activos e inactivos, en que municipios hay más procesos criminales, que tipo de delitos son más comunes, en qué etapa se encuentran y finalmente si hubo imputación de cargos o no,además se buscara mirar si en los procesos hay diferencia entre el año de hecho y el año de la denuncia.

# %% [markdown]
# ##### ***¿Qué?, ¿Porqué? y ¿Cómo?***

# %% [markdown]
#  #####  ¿Qué?

# %% [markdown]
# Basados en el Framework de Tamara, evidenciamos que el Dataset cuenta con atributos categóricos para casi todas las variables excepto las variables de año y total de procesos, municipio y imputación. Las varibles  año y total de procesos son variables ordenadas cuantitativas y la variable total de procesos cuenta con una dirección secuencial, en el caso de la variable imputación  esta cuenta con una escala lógica binaria de SI y NO, la variable municipio cuenta con datos de posición y no tienen un orden. El tipo de Data Set utilizado serán las tablas que contienen clasificaciones, son datos estáticos, es decir, que no cambian en el tiempo. Más adelante se puede hacer una visualización geoespacial.

# %% [markdown]
# #####  ¿Porqué?

# %% [markdown]
# Esta visualización se quiere realizar porque cuenta con los sustantivos y verbos encargados de describir las acciones y objetivos de esta.
# En el caso de los verbos utilizados para la descripción de la visualización, se utilizaron el descubrir y presentar por medio de diferentes DataSet´s que valores atípicos, que comparaciones y que derivaciones pueden tener estas variables. En el caso de la variable municipio se usarán solo los que cuenten con más procesos ya que esta variable está muy desagregada y puede causar problemas visuales en las gráficas, se utilizara para comparar que tipo de delitos son los más frecuentes, en que etapa están este tipo de delitos y si hubo algún tipo de imputación de cargos. Para la variable etapa se puede hacer una derivación de atributos ya que lo que queremos saber es en que fase se encuentran este tipo de procesos y además si estos están activos o no. Con las variables de año lo que se quiere hacer es un paralelo para saber si el año de hecho del delito es diferente al año de la denuncia y de alguna u otra forma saber en que estado se encuentra ese delito.
#
#
# En el caso de los sustantivos que se utilizaron para las variables se tienen en cuenta la dependencia, la similaridad y los datos extremos. Adicionalmente, su searh puede estar representado con un lookup, ya que lo que queremos es buscar e identificar qué pasa con esas variables en los diferentes ámbitos.

# %% [markdown]
# ##### ¿Cómo?

# %% [markdown]
# En el como del Framework de Tamara lo que se quiere es saber de que manera fue echa la visualización, en este caso los atributos y las variables tendrán un color que los identifique, un tamaño y una forma. La visualización será estática, alineada y con dos ejes los cuales expliquen lo dicho anteriormente. Donde el eje “X” llevara la variable categórica y el eje “Y” la cuantitativa, dependiendo lo que se esté analizando. Al utilizar las variables escogidas las visualizaciones que se harán serán barplot´s, pie chart´s o Radial bar chart, en el caso de los barplot lo que se hará son comparaciones entre las diferentes variables, pero una de estas es el tipo de delito y la imputación que tuvieron, para la variable etapa se usara el Radial bar chart el cual nos revelara cuantos procesos hay con esa etapa. Y para la variable estado de la noticia también se harán comparaciones y se buscara analizar si el año afecta el estado en que se encuentre este proceso y por ultimo se hara un daset de partición y tendrá una reducción por ciertos filtros.

# %% [markdown]
# ##### ***Marcas y canales***

# %% [markdown]
# + Los canales utilizados en las visualizaciones serán el área, el color, el volumen para cada atributo, el canal de posición espacial vertical para los atributos cuantitativos y el canal de posición espacial horizontal para los atributos categóricos.
#
# + Las  marcas seran las líneas y las áreas.

# %% [markdown]
# Para las siguientes visualizaciones lo que se hará sera filtrar por municipio los cuales contengan mayor información.

# %%
CONTEO_DE_PROCESOS1 = Base1[Base1.MUNICIPIO.isin(["MEDELLÍN",'IBAGUÉ','VILLAVICENCIO','BUCARAMANGA','CALI','BOGOTÁ, D.C.',
                                           'CÚCUTA','CARTAGENA','PASTO','POPAYÁN','PEREIRA','SANTA MARTA','VALLEDUPAR','NEIVA',
                                            'MONTERÍA','MANIZALES','ARMENIA','SOACHA','BARRANCABERMEJA','PALMIRA','FLORENCIA',
                                            'BELLO','TUNJA','QUIBDO','SINCELEJO','ITAGUI','BUENAVENTURA','YOPAL','RIONEGRO','TULUA'])]

# %% [markdown]
# 1. Lo primero que se quiere hacer es identificar cuantos procesos están activos e
# inactivos, se hará por medio de una tabla, luego se visualizara con un Piechart.

# %%
tab3 = CONTEO_DE_PROCESOS1['ESTADO_NOTICIA'].value_counts().rename_axis('label').reset_index(name='counts');tab3
# Out:
#       label  counts
# 0  INACTIVO  397055
# 1    ACTIVO  194340

# %%
fig1, ax1 = plt.subplots()

ax1.pie(tab3['counts'], 
        labels=tab3['label'],autopct='%1.1f%%')
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# **Que:**
# Basados en el Framework de Tamara, para esta primera visualización lo que se quiere representar es el estado de la noticia criminal al momento de la consulta del dato en el sistema de información, se encuentra evidenciado con un Dataset de tabla que contiene atributos categóricos, y luego explicado en porcentaje.
#
# **Porque:**
# Se quiere mirar el comportamiento y la proporción que tiene el estado de la noticia, donde se descubre y se analiza que tantos procesos están siendo revisados y que tantos no. Además, se identifican ciertas características y se pueden comparar con más cosas más adelantes. Está definida por la forma.
#
# **Como:**
# La visualización cuenta con una gráfica sencilla que compara dos categorías activo e inactivo, se hace por medio de un gráfico de torta, se dan sus respectivos porcentajes y utiliza el canal de color.
#
#
# Los pasos de esta visualización fueron Codificar -> Analizar -> Filtrar -> Gráficar.
#
# **Marcas y Canales:**
# La visualización utiliza la marca de área, y los canales de color y volumen para cada atributo. Estas marcas y canales fueron escogidos ya que visualmente ayudan al receptor a entender lo que se quiere explicar.

# %% [markdown]
# 2. Teniendo en cuenta la primera visualización y sabiendo como se comportaron los datos, el siguiente paso será identificar para esos procesos activos cuantos están en cada etapa.

# %%
CONTEO_DE_activos = CONTEO_DE_PROCESOS1[CONTEO_DE_PROCESOS1.ESTADO_NOTICIA.isin(["ACTIVO"])]

# %%
tab4 = CONTEO_DE_activos['ETAPA'].value_counts().rename_axis('label').reset_index(name='counts')
tab4
# Out:
#                                label  counts
# 0                         INDAGACIÓN  107549
# 1                             JUICIO   47382
# 2                        QUERELLABLE   17696
# 3                      INVESTIGACIÓN   17217
# 4                 EJECUCIÓN DE PENAS    3050
# 5             TERMINACIÓN ANTICIPADA    1407
# 6  ETAPA DE INVESTIGACION PRELIMINAR      24
# 7               ETAPA DE INSTRUCCION      15

# %%
labels = tab4['label']
data = tab4['counts']
#number of data points
n = len(data)
#find max value for full ring
k = 10 ** int(log10(max(data)))
m = k * (1 + max(data) // k)


#radius of donut chart
r = 1.5
#calculate width of each ring
w = r / n 


#create colors along a chosen colormap
colors = [cm.terrain(i / n) for i in range(n)]

#create figure, axis
fig, ax = plt.subplots()
ax.axis("equal")

#create rings of donut chart
for i in range(n):
    #hide labels in segments with textprops: alpha = 0 - transparent, alpha = 1 - visible
    innerring, _ = ax.pie([m - data[i], 
                           data[i]], 
                          radius = r - i * w, 
                          startangle = 90, 
                          labels = ["", labels[i]], 
                          labeldistance = 1 - 1 / (1.5 * (n - i)), 
                          textprops = {"alpha": 0}, 
                          colors = ["white", colors[i]])
    plt.setp(innerring, 
             width = w, 
             edgecolor = "white")
    radius = r - i * w
    plt.text(0, radius - w / 2, f'{labels[i]} – {data[i]} ', ha='right', va='center')
    

plt.show()

# %% [markdown]
# **Que:**
# En esta visualización lo que se quiere representar es la etapa en la que se en cuenta el proceso de los que están activos, se encuentra evidenciado con un Dataset de tabla que contiene atributos categóricos.
#
# **Porque:**
# Se quiere mirar la proporción y cuantos datos tiene cada etapa, con la cual se podrá analizar que tantos procesos están a en cada etapa .
#
# **Como:**
# La visualización cuenta con una gráfica estática que compara diferentes categorías, se hace por medio de un Radial bar chart, donde se muestran sus respectivos valores.
#
#
# Los pasos de esta visualización fueron Codificar -> Analizar -> Filtrar -> Gráficar.
#
# **Marcas y Canales:**
# La visualización utiliza la marca de área, se utilizan los canales de color y volumen para cada atributo de la etapa, son utilizados porque explican de mejor forma visual la etapa en la que esat cada proceso.

# %% [markdown]
# 3. La siguiente visualización lo que quiere explicar es que de los procesos que están activos que municipios de los escogidos contienen más procesos y en que etapas se encuentran.  Además, se utilizará una visualización adicional que conjuntamente contiene el año de denuncia.

# %%
tab1 = pd.crosstab(CONTEO_DE_PROCESOS1["MUNICIPIO"],CONTEO_DE_PROCESOS1["ETAPA"])
tab1
# Out:
# ETAPA            EJECUCIÓN DE PENAS  ETAPA DE INSTRUCCION  \
# MUNICIPIO
# ARMENIA                        2325                     1
# BARRANCABERMEJA                1727                     0
# BELLO                          1563                     0
# BOGOTÁ, D.C.                  15758                    38
# BUCARAMANGA                    3737                     7
# BUENAVENTURA                   1337                     0
# CALI                           8496                     0
# CARTAGENA                      2258                     8
# CÚCUTA                         3739                     5
# FLORENCIA                      1699                     1
# IBAGUÉ                         3555                     5
# ITAGUI                         1430                     0
# MANIZALES                      2878                     0
# MEDELLÍN                      10066                     5
# MONTERÍA                       2129                     5
# NEIVA                          2405                     0
# PALMIRA                        1795                     0
# PASTO                          2335                     0
# PEREIRA                        3041                     9
# POPAYÁN                        2706                     0
# QUIBDO                         1330                     0
# RIONEGRO                       1215                     0
# SANTA MARTA                    1843                    10
# SINCELEJO                      1083                     0
# SOACHA                         1911                     0
# TUNJA                          1447                     2
# VALLEDUPAR                     1983                     0
# VILLAVICENCIO                  3253                     3
# YOPAL                          1049                     1
#
# ETAPA            ETAPA DE INVESTIGACION PRELIMINAR  INDAGACIÓN  INVESTIGACIÓN  \
# MUNICIPIO
# ARMENIA                                        170        7667            677
# BARRANCABERMEJA                                  0        7049            728
# BELLO                                            0        6714            368
# BOGOTÁ, D.C.                                    31       44597           5842
# BUCARAMANGA                                      1       13377           1340
# BUENAVENTURA                                   118        5649            580
# CALI                                            13       19929           3111
# CARTAGENA                                        4       11585           1348
# CÚCUTA                                           3       11544           1482
# FLORENCIA                                       26        6499            604
# IBAGUÉ                                           2       11456           1300
# ITAGUI                                           0        5860            500
# MANIZALES                                        0        7741            669
# MEDELLÍN                                         8       25951           3495
# MONTERÍA                                         0        8586            985
# NEIVA                                            2        8736            879
# PALMIRA                                          0        6431            821
# PASTO                                            2       10661           1258
# PEREIRA                                          5        9536           1183
# POPAYÁN                                          4       10013           1221
# QUIBDO                                           0        6421            685
# RIONEGRO                                         0        5695            391
# SANTA MARTA                                     49       10129            983
# SINCELEJO                                       21        6003            410
# SOACHA                                           0        7125            642
# TUNJA                                           12        6700            349
# VALLEDUPAR                                       6        9220           1022
# VILLAVICENCIO                                    1       13438           1687
# YOPAL                                            0        6131            257
#
# ETAPA            JUICIO  QUERELLABLE  TERMINACIÓN ANTICIPADA
# MUNICIPIO
# ARMENIA            1807         2031                      44
# BARRANCABERMEJA    1967         1550                      31
# BELLO               996         1501                      32
# BOGOTÁ, D.C.      15370        10205                     865
# BUCARAMANGA        4336         3367                     182
# BUENAVENTURA       1279         1271                      22
# CALI               5526         4610                     404
# CARTAGENA          2539         3200                     157
# CÚCUTA             2940         2654                     201
# FLORENCIA          1724         1301                      49
# IBAGUÉ             3839         2504                     197
# ITAGUI             1106         1509                      26
# MANIZALES          1626         1855                      80
# MEDELLÍN           6032         5267                     421
# MONTERÍA           1673         1986                      37
# NEIVA              2183         1941                     131
# PALMIRA            1823         1616                      49
# PASTO              1802         2819                      67
# PEREIRA            2456         2228                     139
# POPAYÁN            2364         2473                     123
# QUIBDO             1296         1175                      59
# RIONEGRO           1071         1301                      18
# SANTA MARTA        1947         2507                     111
# SINCELEJO          1494         1577                       9
# SOACHA             1505         2185                     105
# TUNJA              1038         1575                      48
# VALLEDUPAR         2728         2365                     105
# VILLAVICENCIO      3363         2787                     223
# YOPAL               922         1391                      26

# %%
sns.heatmap(tab1,
                 annot=True, 
                 fmt="d",
                 linewidths=.1,
                 cmap="YlGnBu",
           )
# Out:
# <AxesSubplot:xlabel='ETAPA', ylabel='MUNICIPIO'>

# %%
sns.catplot(data = CONTEO_DE_PROCESOS1,
            kind = "bar",
            estimator = sum,
            x = "ANIO_DENUNCIA", 
            y = "TOTAL_PROCESOS",
            hue = "ETAPA",
            col = "ESTADO_NOTICIA",
            palette = 'rocket',
            ci = None)

# %% [markdown]
# **Que:**  En esta visualización lo que se quiere representar es la etapa en la que se en cuenta el proceso de los que están activos, se encuentra evidenciado con un Dataset de tabla que contiene atributos categóricos, y también se evidencia y se explica el total de procesos que hay en el año de denuncia.
#
# **Porque:**
# Se quiere presentar cuantos datos existen por estado, por municipio, y por año, se utilizara el search, con el cual se identificara y se harán comparaciones.
#
# **Como:**
# La visualización cuenta con una gráfica estática que compara diferentes categorías y  se hace por medio de un gráfico de barras.
#
#
# **Marcas y Canales:**
# La visualización utiliza la marca de lineas, se utilizan los canales de color para el total de los procesos .

# %% [markdown]
# Esta visualización tiene como resultado poder hacer la comparación del año de denuncia con el año de hecho ya que es importante saber si hay diferencia entre estas dos fechas.

# %% [markdown]
# 4. Ahora se hará la misma visualización pero con el año de hecho

# %%
sns.catplot(data = CONTEO_DE_PROCESOS1,
            kind = "bar",
            estimator = sum,
            x = "ANIO_HECHO", 
            y = "TOTAL_PROCESOS",
            hue = "ETAPA",
            col = "ESTADO_NOTICIA",
            palette = 'magma',
            ci = None)

# %% [markdown]
# Como se puede notar no hay mucha diferencia entre las fechas ya que para casi todos los casos en el mismo año en que se hizo la denuncia, fue el año de hecho. Se ven unas pequeñas diferencias en los años de 2010 y 2011 para el estado inactivo.
#
# En el estado activo hay diferencia en el año 2010 puesto que en la gráfica del año de hecho  existen más datos que en la gráfica del año de denuncia.

# %% [markdown]
# 5. La siguiente visualización intenta explicar es que de los procesos que están activos que municipios de los escogidos contienen más procesos y en que etapas se encuentran, adicionalmente, se utilizara la variable total de procesos.

# %%
sns.catplot(data = CONTEO_DE_PROCESOS1,
            kind = "bar",
            estimator = sum,
            x = "TOTAL_PROCESOS", 
            y = "MUNICIPIO",
            hue = "ETAPA",
            col = "ESTADO_NOTICIA",
            palette = 'magma',
            ci = None)

# %% [markdown]
# **Que:** En esta visualización lo que se quiere explicar es que de las etapas en la que se en cuentran los procesos, de los municipios escogidos cuantos procesos exiten en cada uno, se hará por medio de un Dataset de tabla que contiene los diferentes atributos.
#
# **Porque:** Se quiere mirar cuantos datos tiene cada municipio, que etapa es la que más se evidencia y en que estado es en que se encuentran estas.
#
# **Como:** La visualización cuenta con una gráfica estática que compara diferentes categorías, se hace por medio de un gráfico de barras veritcal, donde se muestran sus respectivos valores.
#
#
# **Marcas y Canales:** La visualización utiliza la marca de área, se utilizan los canales de color y volumen para cada atributo de la etapa, son utilizados porque explican de mejor forma visual la etapa en la que esta cada proceso.

# %% [markdown]
# En esta visualización se confirma que como hay pocos procesos activos ya que las barras son demasiado pequeñas y no las toma para los municipios filtrados, en el caso de los procesos inactivos si se puede ver que todos los municipios tienen valores por lo cual se confirma que los procesos inactivos son más comunes que los activos, además, que el municipio con más casos inactivos es Bogotá,  seguidos de Medellín y Cali, estos casos que son inactivos son más comunes en la etapa de indagación y juicio, por lo cual se da una idea acerca del objetivo del Framework.

# %%
sns.barplot(data = CONTEO_DE_PROCESOS1,
            estimator = sum,
            x = "TOTAL_PROCESOS", 
            y = "MUNICIPIO",
            ci = None)
# Out:
# <AxesSubplot:xlabel='TOTAL_PROCESOS', ylabel='MUNICIPIO'>

# %% [markdown]
# Para esta visualización lo que se quiere es ver que de los municipios escogidos cuales contenian más procesos para confirmar lo dicho anteriormente.

# %%
CONTEO_DE_PROCESOS1.describe()
# Out:
#        ANIO_DENUNCIA  ANIO_ENTRADA  ANIO_HECHO  TOTAL_PROCESOS
# count      591395.00     591395.00   591395.00       591395.00
# mean         2015.28       2015.46     2014.75           13.82
# std             2.99          3.01        3.02          287.13
# min          2005.00       2005.00     2010.00            1.00
# 25%          2013.00       2013.00     2012.00            1.00
# 50%          2015.00       2016.00     2015.00            1.00
# 75%          2018.00       2018.00     2017.00            3.00
# max          2021.00       2021.00     2205.00       116668.00

# %%
import altair as alt
from vega_datasets import data
from altair import datum

alt.Chart(CONTEO_DE_PROCESOS1.sample(50)).transform_window(
    index='count()'
).transform_fold(
    ['ANIO_DENUNCIA', 'ANIO_ENTRADA', 'ANIO_HECHO', 'TOTAL_PROCESOS']
).transform_joinaggregate(
     min='min(value)',
     max='max(value)',
     groupby=['key']
).transform_calculate(
    minmax_value=(datum.value-datum.min)/(datum.max-datum.min),
    mid=(datum.min+datum.max)/2
).mark_line().encode(
    x='key:N',
    y='minmax_value:Q',
    color='CONTEO_DE_PROCESOS1:N',
    detail='index:N',
    opacity=alt.value(0.5)
).properties(width=500)
# Out:
# alt.Chart(...)

# %% [markdown]
# # TERCER CORTE

# %%
CONTEO_DE_PROCESOS1 = CONTEO_DE_PROCESOS[CONTEO_DE_PROCESOS.MUNICIPIO.isin(["MEDELLÍN",'IBAGUÉ','VILLAVICENCIO','BUCARAMANGA','CALI','BOGOTÁ, D.C.',
                                           'CÚCUTA','CARTAGENA','PASTO','POPAYÁN','PEREIRA','SANTA MARTA','VALLEDUPAR','NEIVA',
                                            'MONTERÍA','MANIZALES','ARMENIA','SOACHA','BARRANCABERMEJA','PALMIRA','FLORENCIA',
                                            'BELLO','TUNJA','QUIBDO','SINCELEJO','ITAGUI','BUENAVENTURA','YOPAL','RIONEGRO','TULUA'])]

# %%
CONTEO_DE_PROCESOS1 = CONTEO_DE_PROCESOS1[CONTEO_DE_PROCESOS1.GRUPO_DELITO.isin(["DELITOS SEXUALES",'EXTORSION','VIOLENCIA INTRAFAMILIAR',
                                                                              'DESAPARICION FORZADA','HURTO','ESTUPEFACIENTES'])]

# %%
tab1 = pd.crosstab(CONTEO_DE_PROCESOS1["MUNICIPIO"],CONTEO_DE_PROCESOS1["GRUPO_DELITO"])

# %%
import plotly.graph_objects as go

fig = go.Figure(data=CONTEO_DE_PROCESOS1.Heatmap(
        z=GRUPO_DELITO,
        x= TOTAL_PROCESOS,
        y= MUNICIPIO,
        colorscale='Viridis'))

fig.update_layout(
    title='GitHub commits per day',
    xaxis_nticks=36)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-a9640d7aa188> in <module>
#       1 import plotly.graph_objects as go
#       2
# ----> 3 fig = go.Figure(data=CONTEO_DE_PROCESOS1.Heatmap(
#       4         tab1,
#       5         colorscale='Viridis'))
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5460             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5461                 return self[name]
# -> 5462             return object.__getattribute__(self, name)
#    5463
#    5464     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Heatmap'
